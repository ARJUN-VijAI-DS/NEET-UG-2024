# %%
# importing libraries
import pandas as pd                  # Preparing high-level data sets, etc.
import numpy as np                   # library for multi-dimensional array, matrix processing, etc.
import matplotlib.pyplot as plt      # Visualization Library
import seaborn as sns                # Visualization Library 
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\user\\Desktop\\NEET DATA_ Analysis\\ANDAMAN AND NICOBAR ISLANDS (UT) NEET UG 2024.csv')
df.head()
# Out:
#    marks                             state        city  \
# 0     46  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1    226  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 2    449  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 3    424  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 4    222  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
#
#                 center_name  center_number
# 0  KENDRIYA VIDYALAYA NO. 1         110101
# 1  KENDRIYA VIDYALAYA NO. 1         110101
# 2  KENDRIYA VIDYALAYA NO. 1         110101
# 3  KENDRIYA VIDYALAYA NO. 1         110101
# 4  KENDRIYA VIDYALAYA NO. 1         110101

# %%
df.shape
# Shape of the Data Set
# Out:
# (1025, 5)

# %%
# General Information of the DataFrame/Data Sheet
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   marks          1025 non-null   int64
#  1   state          1025 non-null   object
#  2   city           1025 non-null   object
#  3   center_name    1025 non-null   object
#  4   center_number  1025 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 40.2+ KB

# %%
# General Information of the DataFrame/Data Sheet
df.info
# Out:
# <bound method DataFrame.info of       marks                             state        city  \
# 0        46  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1       226  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 2       449  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 3       424  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 4       222  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# ...     ...                               ...         ...
# 1020    264  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1021     42  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1022    334  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1023    238  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1024    145  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
#
#                                    center_name  center_number
# 0                     KENDRIYA VIDYALAYA NO. 1         110101
# 1                     KENDRIYA VIDYALAYA NO. 1         110101
# ...

# %%
# Checking data types in the DataFrame/Data Sheet
df.dtypes
# Out:
# marks             int64
# state            object
# city             object
# center_name      object
# center_number     int64
# dtype: object

# %%
df.describe()
# Description of the the Data Set
# Out:
#              marks  center_number
# count  1025.000000    1025.000000
# mean    192.737561  110101.650732
# std     126.354313       0.654732
# min      -5.000000  110101.000000
# 25%     103.000000  110101.000000
# 50%     155.000000  110102.000000
# 75%     263.000000  110102.000000
# max     680.000000  110103.000000

# %%
df.isnull().sum()
# No null values in the Data Set
# Out:
# marks            0
# state            0
# city             0
# center_name      0
# center_number    0
# dtype: int64

# %%
# Checking Missing Values
df.isna().any()
# Out:
# marks            False
# state            False
# city             False
# center_name      False
# center_number    False
# dtype: bool

# %%
# Create a deep copy of the DataFrame
df_copy = df.copy(deep=True)

df_copy.head()
# Out:
#    marks                             state        city  \
# 0     46  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1    226  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 2    449  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 3    424  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 4    222  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
#
#                 center_name  center_number
# 0  KENDRIYA VIDYALAYA NO. 1         110101
# 1  KENDRIYA VIDYALAYA NO. 1         110101
# 2  KENDRIYA VIDYALAYA NO. 1         110101
# 3  KENDRIYA VIDYALAYA NO. 1         110101
# 4  KENDRIYA VIDYALAYA NO. 1         110101

# %%
df_copy.tail()
# Out:
#       marks                             state        city  \
# 1020    264  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1021     42  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1022    334  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1023    238  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
# 1024    145  ANDAMAN AND NICOBAR ISLANDS (UT)  PORT BLAIR
#
#                                    center_name  center_number
# 1020  GOVERNMENT MODEL SENIOR SECONDARY SCHOOL         110103
# 1021  GOVERNMENT MODEL SENIOR SECONDARY SCHOOL         110103
# 1022  GOVERNMENT MODEL SENIOR SECONDARY SCHOOL         110103
# 1023  GOVERNMENT MODEL SENIOR SECONDARY SCHOOL         110103
# 1024  GOVERNMENT MODEL SENIOR SECONDARY SCHOOL         110103

# %%
df_copy.drop(columns=["state","city", "center_name"],inplace=True)

# Comment 1:
# The "state and city" columns can be dropped from the dataset as it contains only a single, 
## consistent value ("ANDAMAN AND NICOBAR ISLANDS (UT) and PORT BLAIR") and therefore provides 
### no additional information for analysis.

# Comment 2:
# The "center_name" column can be dropped from the dataset as the columns "center_name" and 
## "center_number" could be considered synonymous for the purpose of this analysis.


df_copy.head(),df_copy.shape
# Out:
# (   marks  center_number
#  0     46         110101
#  1    226         110101
#  2    449         110101
#  3    424         110101
#  4    222         110101,
#  (1025, 2))

# %%
import seaborn as sns             # Visualization Library
import matplotlib.pyplot as plt   # Visualization Library

# Assuming df_copy is already defined as the DataFrame
for col in df_copy.columns:
    if df_copy[col].dtype == "int64":
        value_counts = df_copy[col].value_counts()
        print(f"Value counts for the column '{col}' are: \n\n{value_counts}\n")
        
        # Create a figure with three subplots: one for displot, one for scatter plot, and one 
        ## for boxplot
        fig, ax = plt.subplots(3, 1, figsize=(5, 5), gridspec_kw={'height_ratios': [5, 5, 2]})
        
        # Plotting the histogram and KDE
        sns.histplot(df_copy[col], kde=True, ax=ax[0])
        ax[0].set_title(f'Distribution of {col}')
        
        # Plotting the scatter plot
        sns.scatterplot(x=df_copy[col], y=df_copy.index, ax=ax[1])
        ax[1].set_title(f'Scatter Plot of {col}')
        ax[1].set_xlabel(col)
        ax[1].set_ylabel('Index')
        
        # Plotting the boxplot
        sns.boxplot(x=df_copy[col], ax=ax[2])
        ax[2].set_title(f'Boxplot of {col}')
        ax[2].set_xlabel(col)
        
        # Display the plots
        plt.tight_layout()
        plt.show()
# Out:
# Value counts for the column 'marks' are:
#
# 105    14
# 110    12
# 144     9
# 75      9
# 100     9
#        ..
# 318     1
# 559     1
# 435     1
# 302     1
# 333     1
# Name: marks, Length: 396, dtype: int64
# Value counts for the column 'center_number' are:
#
# 110101    461
# 110102    461
# 110103    103
# Name: center_number, dtype: int64

# %%
df_copy.skew()
# Out:
# marks            1.051346
# center_number    0.507661
# Agg_Cluster      2.415286
# dtype: float64

# %%
df_copy.kurtosis()
# Out:
# marks            0.738507
# center_number   -0.705437
# Agg_Cluster      3.841099
# dtype: float64

# %%
# Comment
## The marks greater than 5 are of the regions of North and West where the paper leak 
### scam had happened in 2024

df_copy.loc[df_copy["marks"]>530]
# Out:
#      marks  center_number  Agg_Cluster
# 27     544         110101            1
# 37     559         110101            1
# 40     580         110101            1
# 55     680         110101            1
# 104    579         110101            1
# 258    540         110101            1
# 334    620         110101            1
# 382    552         110101            1
# 409    568         110101            1
# 464    543         110102            1
# 483    542         110102            1
# 618    548         110102            1
# 635    657         110102            1
# 653    578         110102            1
# 912    670         110102            1
# 981    648         110103            1

# %%
Percentage_High_Score = [df_copy["marks"]>530].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 Percentage_High_Score = [df_copy["marks"]>530].count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
P = (df_copy.loc[df_copy["marks"]>530].count()/ df_copy.loc[df_copy["marks"]].count())*100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 P = (df_copy.loc[df_copy["marks"]>530].count()/ df_copy.loc[df_copy["marks"]].count())*100
#
# File e:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File e:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
#    1304 if is_nested_tuple(key, labels):
#
# ...

# %%
P = [df_copy.loc[df_copy["marks"]>530].count()/ df_copy.loc[df_copy["marks"]].count()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 P = [df_copy.loc[df_copy["marks"]>530].count()/ df_copy.loc[df_copy["marks"]].count()]
#
# File e:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File e:\Users\user\anaconda3\lib\site-packages\pandas\core\indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
#    1304 if is_nested_tuple(key, labels):
#
# ...

# %%
x1 = df_copy.loc[df_copy["marks"]>530].count()
x1
# Out:
# marks            16
# center_number    16
# Agg_Cluster      16
# dtype: int64

# %%
p = df_copy["marks"].count()
p
# Out:
# 1025

# %%
percentage_high_score = (x1/p)*100
percentage_high_score

## Percentage of marks above 530 is ONLY! 1.560976 % which is absolutely Normal condition.
# Out:
# marks            1.560976
# center_number    1.560976
# Agg_Cluster      1.560976
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# Select relevant features for clustering
features = df_copy[['marks', 'center_number']]

# Standardize the features
scaler = StandardScaler() 
## Sclaing is done as clustering is distance based -- Read in DETAIL
scaled_features = scaler.fit_transform(features)

# Here feature "Genre" is not used.........Important...
## Here we are standerdising "AS WE HAVE TO CALCULATE THE DISTANCE BETWEEN THE POINTS"

# %%
# Visualize the Dendrogram to show the hierarchical clustering
import scipy.cluster.hierarchy as sch
plt.figure(figsize=(15,7))
dendrogram = sch.dendrogram(sch.linkage(scaled_features, method='complete'))
plt.title('Dendrogram')
plt.xlabel('Marks')
plt.ylabel('Euclidean distances')
plt.show()

### Based on Different colours shown in the dendrogram -- Coustomers are divided in 
#### "FOUR different clusters"

# %%
from sklearn.cluster import AgglomerativeClustering

agg_cluster = AgglomerativeClustering(n_clusters=2, metric='euclidean', linkage='complete')
agg_clusters = agg_cluster.fit_predict(scaled_features)

# Add the Agglomerative Clustering labels to the dataset
df_copy['Agg_Cluster'] = agg_clusters

# %% [markdown]
# <font size = 5.5>**Visualizing the clusters using features of the dataset**

# %%
plt.figure(figsize=(10, 7))
plt.scatter(df_copy['marks'], df_copy['center_number'], c=df_copy['Agg_Cluster'], cmap='rainbow', marker='o')
plt.title('Customer Segments (Agglomerative Clustering)')
plt.xlabel('Marks')
plt.ylabel('Center Code')
plt.colorbar(label='Optimal_Agg_Cluster')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.scatter(df_copy['center_number'], df_copy['marks'], c=df_copy['Agg_Cluster'], cmap='rainbow', marker='o')
plt.title('Customer Segments (Agglomerative Clustering)')
plt.xlabel('Center Code')
plt.ylabel('Marks')
plt.colorbar(label='Optimal_Agg_Cluster')
plt.grid(True)
plt.show()

# %%
x = (df_copy.loc[df_copy["marks"]>530] / df_copy.loc[df_copy["marks"]>-6])*100
x
# Out:
#       marks  center_number  Agg_Cluster
# 0       NaN            NaN          NaN
# 1       NaN            NaN          NaN
# 2       NaN            NaN          NaN
# 3       NaN            NaN          NaN
# 4       NaN            NaN          NaN
# ...     ...            ...          ...
# 1020    NaN            NaN          NaN
# 1021    NaN            NaN          NaN
# 1022    NaN            NaN          NaN
# 1023    NaN            NaN          NaN
# 1024    NaN            NaN          NaN
#
# [1025 rows x 3 columns]
