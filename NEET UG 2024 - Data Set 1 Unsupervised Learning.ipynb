# %% [markdown]
# <font size = 5.5> **Problem Statement**

# %% [markdown]
# <font size = 4.5> **Case -1**
#     <br><br>Suppose you are from the National Testing Agency (NTA). How will you prove that there was no discrepancy in the NEET examination? What assumptions and hypotheses will you present before the Supreme Court?
#     <br><br>**Case -2**
#     <br><br>If you are a student, how will your advocate oppose the NTA’s side that there was no discrepancy in the NEET Examination?

# %%
# importing libraries
import pandas as pd                  # Preparing high-level data sets, etc.
import numpy as np                   # library for multi-dimensional array, matrix processing, etc.
import matplotlib.pyplot as plt      # Visualization Library
import seaborn as sns                # Visualization Library 
# %matplotlib inline

# %%
# Data Set Provied by Dr. Joshi Sir.

data_2024_detailed = {
    'Year': [2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024],
    
'Region': ['North', 'South', 'East', 'West', 'North', 'South', 'West', 'East', 'North'],

    'Exam Center': ['A', 'B', 'C', 'D', 'A', 'B', 'D', 'C', 'A'],

    'Type of Scam': ['Paper Leak', 'None', 'None', 'Paper Leak', 'Paper Leak', 'None', 'Paper Leak', 'None', 'Paper Leak'],

    'Number of Cases': [10, 0, 0, 12, 7, 0, 15, 0, 8],

    'Actions Taken': ['Exams Cancelled', 'None', 'None', 'Exams Cancelled', 'Exams Cancelled', 'None', 'Exams Cancelled', 'None', 'Exams Cancelled'],

    'Average Marks': [85, 81, 78, 88, 83, 80, 90, 79, 84],

    'Topper Marks': [100, 99, 98, 100, 100, 99, 100, 98, 100],

    'Number of Toppers': [10, 8, 5, 12, 9, 7, 14, 5, 11],

    'Number of Successful Candidates': [200, 205, 180, 190, 210, 200, 195, 185, 205],

    'Number of Perfect Scores': [5, 2, 1, 6, 4, 2, 7, 1, 5]}

# %%
DF = pd.DataFrame(data_2024_detailed)

# Converting the Data given into DataFrame

# %% [markdown]
# <font size = 5.5> **Objective and Explanation of Features of Data Set**

# %% [markdown]
# <font size = 4.5>The objective of this data set is to provide detailed information and evidence to support the claim that there was a significant leak of examination papers in the year 2024. By examining various metrics across different regions and exam centers, the data aims to highlight discrepancies and anomalies that indicate malpractice, specifically paper leaks. The key elements include:
#     <br><br>**Identification of Paper Leaks:** The data categorizes instances of paper leaks across different regions and exam centers.
#     <br><br>**Quantification of Cases:** The number of paper leak cases is recorded, showing regions and centers with higher occurrences.
#     <br><br>**Impact Analysis:** The impact of these leaks on examinations, such as the cancellation of exams and changes in average marks, topper marks, and the number of successful candidates.
#     <br><br>**Actions Taken:** Documentation of actions taken in response to these leaks, such as the cancellation of exams, to demonstrate the severity and response to the issue.
#     <br><br>**Performance Metrics:** Analysis of average marks, topper marks, number of toppers, number of successful candidates, and the number of perfect scores to identify irregularities that could indicate the influence of leaked papers.
#     <br><br>By aggregating and analyzing this data, we aim to present a comprehensive view that supports the assertion of paper leaks, demonstrating their occurrence, impact, and the measures taken in response.

# %% [markdown]
# <font size = 4.5> **Description of All Columns**
#     <br><br>**Year:** Represents the calendar year in which the data was collected, specifically focusing on the year 2024.
#     <br><br>**Region:** Indicates the geographical area where the examination centers are located. The regions included in the data are North, South, East, and West.<br><br>
#     **Exam Center:** Specifies the individual examination center within each region. Each center is denoted by a letter (A, B, C, D).
#     <br><br>**Type of Scam:** Describes the type of irregularity or malpractice reported at the exam center. This column highlights whether there was a 'Paper Leak' or if there were 'None' (no scams reported).
#     <br><br>**Number of Cases:** Denotes the number of reported cases of the specified type of scam (e.g., paper leaks) at each exam center.
#     <br><br>**Actions Taken:** Lists the measures implemented in response to the reported scams. Actions could include 'Exams Cancelled' or 'None' (indicating no actions were taken).
#     <br><br>**Average Marks:** Shows the average score obtained by candidates in each region and exam center.
#     <br><br>**Topper Marks:** Displays the highest marks achieved by the top-performing student(s) at each exam center.
#     <br><br>**Number of Toppers:** Indicates the number of students who scored the highest marks at each exam center.
#     <br><br>**Number of Successful Candidates:** Represents the total number of candidates who passed the examination at each exam center.
#     <br><br>**Number of Perfect Scores:** Shows the number of students who achieved a perfect score in the examination at each exam center.
#     <br><br>These columns collectively provide a comprehensive overview of the examination process, the occurrence of paper leaks, and their subsequent impact on the performance and outcomes of the candidates.

# %%
df = pd.read_csv("C:\\Users\\user\\Desktop\\NEET DATA_ Analysis\\data_2024_detailed.csv")
df
# Reading of Data Set from .csv file.
# Out:
#    Year Region Exam Center Type of Scam  Number of Cases    Actions Taken  \
# 0  2024  North           A   Paper Leak               10  Exams Cancelled
# 1  2024  South           B         None                0             None
# 2  2024   East           C         None                0             None
# 3  2024   West           D   Paper Leak               12  Exams Cancelled
# 4  2024  North           A   Paper Leak                7  Exams Cancelled
# 5  2024  South           B         None                0             None
# 6  2024   West           D   Paper Leak               15  Exams Cancelled
# 7  2024   East           C         None                0             None
# 8  2024  North           A   Paper Leak                8  Exams Cancelled
#
#    Average Marks  Topper Marks  Number of Toppers  \
# 0             85           100                 10
# 1             81            99                  8
# 2             78            98                  5
# ...

# %%
df.shape
# Shape of the Data Set
# Out:
# (9, 11)

# %%
df.describe()
# Description of the the Data Set
# Out:
#          Year  Number of Cases  Average Marks  Topper Marks  \
# count     9.0         9.000000       9.000000      9.000000
# mean   2024.0         5.777778      83.111111     99.333333
# std       0.0         5.932491       4.075673      0.866025
# min    2024.0         0.000000      78.000000     98.000000
# 25%    2024.0         0.000000      80.000000     99.000000
# 50%    2024.0         7.000000      83.000000    100.000000
# 75%    2024.0        10.000000      85.000000    100.000000
# max    2024.0        15.000000      90.000000    100.000000
#
#        Number of Toppers  Number of Successful Candidates  \
# count           9.000000                         9.000000
# mean            9.000000                       196.666667
# std             3.082207                        10.000000
# min             5.000000                       180.000000
# 25%             7.000000                       190.000000
# 50%             9.000000                       200.000000
# ...

# %%
# General Information of the DataFrame/Data Sheet
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             9 non-null      int64
#  1   Region                           9 non-null      object
#  2   Exam Center                      9 non-null      object
#  3   Type of Scam                     9 non-null      object
#  4   Number of Cases                  9 non-null      int64
#  5   Actions Taken                    9 non-null      object
#  6   Average Marks                    9 non-null      int64
#  7   Topper Marks                     9 non-null      int64
#  8   Number of Toppers                9 non-null      int64
#  9   Number of Successful Candidates  9 non-null      int64
#  10  Number of Perfect Scores         9 non-null      int64
# dtypes: int64(7), object(4)
# memory usage: 920.0+ bytes

# %%
# Checking data types in the DataFrame/Data Sheet
df.dtypes
# Out:
# Year                                int64
# Region                             object
# Exam Center                        object
# Type of Scam                       object
# Number of Cases                     int64
# Actions Taken                      object
# Average Marks                       int64
# Topper Marks                        int64
# Number of Toppers                   int64
# Number of Successful Candidates     int64
# Number of Perfect Scores            int64
# dtype: object

# %%
df.isnull().sum()
# No null values in the Data Set
# Out:
# Year                               0
# Region                             0
# Exam Center                        0
# Type of Scam                       0
# Number of Cases                    0
# Actions Taken                      0
# Average Marks                      0
# Topper Marks                       0
# Number of Toppers                  0
# Number of Successful Candidates    0
# Number of Perfect Scores           0
# dtype: int64

# %%
# Checking Missing Values
df.isna().any()
# Out:
# Year                               False
# Region                             False
# Exam Center                        False
# Type of Scam                       False
# Number of Cases                    False
# Actions Taken                      False
# Average Marks                      False
# Topper Marks                       False
# Number of Toppers                  False
# Number of Successful Candidates    False
# Number of Perfect Scores           False
# dtype: bool

# %%
# Create a deep copy of the DataFrame
DF_COPY = df.copy(deep=True)

DF_COPY
# Out:
#    Year Region Exam Center Type of Scam  Number of Cases    Actions Taken  \
# 0  2024  North           A   Paper Leak               10  Exams Cancelled
# 1  2024  South           B         None                0             None
# 2  2024   East           C         None                0             None
# 3  2024   West           D   Paper Leak               12  Exams Cancelled
# 4  2024  North           A   Paper Leak                7  Exams Cancelled
# 5  2024  South           B         None                0             None
# 6  2024   West           D   Paper Leak               15  Exams Cancelled
# 7  2024   East           C         None                0             None
# 8  2024  North           A   Paper Leak                8  Exams Cancelled
#
#    Average Marks  Topper Marks  Number of Toppers  \
# 0             85           100                 10
# 1             81            99                  8
# 2             78            98                  5
# ...

# %% [markdown]
# <font size = 5.5> **Data Visualization** <br><br>Graphical representations make it easier to see patterns, trends, and outliers.

# %% [markdown]
# <font size = 5.5>**1. Histograms:** Show the distribution of a single numerical variable.<br><br>**2. Box Plots:** Box plots help identify outliers and the spread of the data.<br><br>**3. Scatter Plot:** Used to visualize the relationship between two numerical variables.

# %%
import seaborn as sns             # Visualization Library
import matplotlib.pyplot as plt   # Visualization Library

# Assuming DF_COPY is already defined as the DataFrame
for col in DF_COPY.columns:
    if DF_COPY[col].dtype == "int64":
        value_counts = DF_COPY[col].value_counts()
        print(f"Value counts for the column '{col}' are: \n\n{value_counts}\n")
        
        # Create a figure with three subplots: one for displot, one for scatter plot, and one for boxplot
        fig, ax = plt.subplots(3, 1, figsize=(5, 5), gridspec_kw={'height_ratios': [5, 5, 2]})
        
        # Plotting the histogram and KDE
        sns.histplot(DF_COPY[col], kde=True, ax=ax[0])
        ax[0].set_title(f'Distribution of {col}')
        
        # Plotting the scatter plot
        sns.scatterplot(x=DF_COPY[col], y=DF_COPY.index, ax=ax[1])
        ax[1].set_title(f'Scatter Plot of {col}')
        ax[1].set_xlabel(col)
        ax[1].set_ylabel('Index')
        
        # Plotting the boxplot
        sns.boxplot(x=DF_COPY[col], ax=ax[2])
        ax[2].set_title(f'Boxplot of {col}')
        ax[2].set_xlabel(col)
        
        # Display the plots
        plt.tight_layout()
        plt.show()
# Out:
# Value counts for the column 'Year' are:
#
# 2024    9
# Name: Year, dtype: int64
# Value counts for the column 'Number of Cases' are:
#
# 0     4
# 10    1
# 12    1
# 7     1
# 15    1
# 8     1
# Name: Number of Cases, dtype: int64
# Value counts for the column 'Average Marks' are:
#
# 85    1
# 81    1
# 78    1
# 88    1
# 83    1
# 80    1
# 90    1
# 79    1
# 84    1
# Name: Average Marks, dtype: int64
# Value counts for the column 'Topper Marks' are:
#
# 100    5
# 99     2
# 98     2
# Name: Topper Marks, dtype: int64
# Value counts for the column 'Number of Toppers' are:
#
# 5     2
# 10    1
# 8     1
# 12    1
# 9     1
# 7     1
# 14    1
# 11    1
# Name: Number of Toppers, dtype: int64
# Value counts for the column 'Number of Successful Candidates' are:
#
# 200    2
# 205    2
# 180    1
# 190    1
# 210    1
# 195    1
# 185    1
# Name: Number of Successful Candidates, dtype: int64
# Value counts for the column 'Number of Perfect Scores' are:
#
# 5    2
# 2    2
# ...

# %%
# Select the two columns for the bar graph
Region = DF_COPY["Region"]
Number_of_Cases = DF_COPY["Number of Cases"]

# Create the bar graph
plt.figure(figsize=(5, 5))
plt.bar(Region, Number_of_Cases, color='blue')

# Add titles and labels
plt.title('Bar Graph between Region and Number of Cases')
plt.xlabel('Region')
plt.ylabel('Number of Cases')

# Display the plot
plt.show()

# %% [markdown]
# <font size = 5.5> **Analysis of Each Graph One by one**

# %% [markdown]
# ## Column -  Year
# - 1. Since only the year "2024" is provided, it doesn't hold much weight in terms of comprehensive data.

# %% [markdown]
# ## Column - Number of Cases
# - The histogram shows that the number of cases is skewed to the right, with a higher frequency of cases occurring at the lower end of the scale (0-2 cases).
# - There are fewer occurrences as the number of cases increases, indicating that higher case numbers are less common.
#
# **Outliers in the Data**:
#    - No outliers
#
# **Variability in Number of Cases**:
#    - The boxplot indicates a wide range of values for the number of cases, with the interquartile range (IQR) = 10, Q1= 00, Q3 = 10, and lower and upper bounds are -15 and 25.
#    - The median number of cases = 7, showing a central tendency towards the lower end of the scale.
#
# **Asymmetry of Data**:
#    - Both the histogram and boxplot suggest that the data is right-skewed. The longer tail on the right side of the histogram and the median being closer to the lower quartile in the boxplot support this observation.
#
# **Overall Range of Cases**:
#    - The number of cases ranges from 0 to 15, as shown in all three graphs. This wide range indicates considerable variability in the number of cases.

# %% [markdown]
# ## Column - Average Marks
#
# - The histogram shows that average marks are spread across the range of 78 to 90.
# - Most students have marks clustered around 80-85, indicating a common performance level.
#
# **Outliers in Marks:**
# - The scatter plot reveals no significant outliers as all points are relatively aligned horizontally, suggesting that the average marks are consistently distributed without extreme deviations.
#
# **Variability in Marks:**
#
# - The boxplot indicates that the interquartile range (IQR) for the average marks is 5 with Q1 =80 and Q3 = 85, lower and upper bounds are 72.5 and 92.5, meaning the middle 50% of the data lies within this range.
# - There are no extreme outliers visible in the boxplot, which supports the finding from the scatter plot.
#
# **Symmetry of Data:**
#
# - The distribution appears slightly skewed to the right, as suggested by the histogram and boxplot. The tail of the histogram is longer on the right side, and the median line in the boxplot is closer to the lower quartile (median = 83).
#
# **Overall Performance Range:**
#
# - The marks range from 78 to 90, as shown in all three graphs. This indicates that while there is some variability, the students' average marks are fairly close to each other, with no drastic variations.

# %% [markdown]
# ## Column - Topper Marks:
#
# - The histogram shows that most topper marks are clustered around the highest value, which is 100. The distribution indicates a right-skewed pattern with a concentration of higher marks.
#
# **Frequency of Topper Marks:**
#
# - The highest frequency of topper marks is at the value of 100, indicating that a significant number of top students achieved perfect scores.
# - There are fewer students with marks below 99, showing that achieving close to perfect scores is less common.
#
# **Outliers in Topper Marks:**
#
# - The scatter plot indicates that the marks are generally clustered, with no significant outliers. The data points are fairly aligned horizontally, suggesting consistency in the topper marks.
#
# **Variability in Topper Marks:**
#
# - The boxplot indicates a range of topper marks from approximately 98 to 100. The interquartile range (IQR) is 1 with Q1 = 99 and Q3 = 100, and lower and upper bounds are 97.5 and 101.5.
# - There is a slight variability within this high-performance group, but most marks are close to perfect.
#
# **Skewness of Data:**
#
# - Both the histogram and boxplot suggest that the topper marks data is right-skewed. The longer tail on the left side of the histogram and the median line closer to the upper quartile in the boxplot support this observation.

# %% [markdown]
# ## Column - Number of Toppers:
#
# - The histogram shows a roughly uniform distribution of the number of toppers across the range. There is no single range that dominates the distribution, indicating that the number of toppers varies widely.
#
# **Median and Spread:**
#
# - The boxplot indicates that the median number of toppers is 9. The interquartile range (IQR) is 4 [Q1= 7, Q3 = 11, and lower and upper bounds are 1 and 17], shows that the middle 50% of the data lies within this range.
#
# **Symmetry in Data:**
#
# - The histogram and boxplot together suggest that the distribution of the number of toppers is relatively symmetric. The median is centrally located within the IQR, and there are no extreme outliers on either end.
#
# **Data Clusters:**
#
# - The scatter plot shows that the data points are relatively spread out but still within a close range, with no significant clustering or gaps. This indicates a consistent distribution without any unusual concentrations of values.
#
# **Range and Extremes:**
#
# - The number of toppers ranges from 5 to 14, as seen in both the scatter plot and the boxplot. This wide range shows significant variation in the number of toppers among different regions or exam centers.

# %% [markdown]
# ## Column - Successful Candidates
#
# **Histogram Distribution:**
#
# - The histogram shows that the distribution of the number of successful candidates is somewhat right-skewed. The higher frequencies are at the upper end of the range, especially around 205-210 candidates.
#
# **Variability and Outliers:**
#
# The scatter plot displays the number of successful candidates spread across the entire range, with no significant clustering. This suggests a relatively uniform distribution of successful candidates among different groups or regions.
#
# **Median and Quartiles:**
#
# - The boxplot shows the median number of successful candidates is 200. The interquartile range (IQR) is 15, Q1 = 190 , Q3 = 205, and lower and upper bounds are 167.5 and 227.5, indicating that the middle 50% of the data lies within this range.
#
# **Range of Data:**
#
# - The number of successful candidates ranges from 180 to 210, as seen in all three graphs. This indicates a fairly wide range, with candidates’ numbers varying significantly between different regions or groups.
#
# **Potential Outliers:**
#
# - There are no significant outliers visible in the boxplot, suggesting that the data points are consistently within the expected range. This consistency is further reflected in the scatter plot, where all points lie relatively close to the median line.
#
# **These points provide detailed insights into the distribution, variability, and consistency of the number of successful candidates.**

# %% [markdown]
# ## Column - Number of Perfect Scores
#
# **Histogram:**
#
# - The distribution shows that the most common number of perfect scores is 1, with 4 occurrences.
# - There is a noticeable drop-off after 1 perfect score, with counts of 1 or 2 for other numbers of perfect scores, suggesting that achieving multiple perfect scores is less common.
# - The distribution is right-skewed, indicating that higher numbers of perfect scores are less frequent.
#
# **Scatter Plot:**
#
# - The scatter plot shows individual data points for the number of perfect scores, plotted against an index (possibly representing different students or entities).
# - Most data points are clustered towards the lower end of the perfect score spectrum, reinforcing the histogram’s finding that fewer perfect scores are more common.
# - There are outliers with higher numbers of perfect scores, indicating that a small number of students or entities consistently achieve high performance.
#
# **Boxplot:**
#
# - The boxplot provides a summary of the distribution of perfect scores, with the median = 4.
# - The interquartile range (IQR) is 3, Q1 =2, Q3 = 5, and lower bound and upper bounds are -2.5 and 9.5, showing that the middle 50% of the data falls within this range.
# - There are no apparent outliers outside the whiskers, indicating that extreme values are not present or have minimal impact on the overall distribution.
#
# **Central Tendency and Spread:**
#
# - The median number of perfect scores (median = 4) suggests that half of the data falls below and half above this value.
# - The spread of data, with perfect scores ranging from 1 to 7, indicates a diverse range of performance levels.
#
# **Overall Insights:**
#
# - Most individuals/entities tend to have a lower number of perfect scores, with only a few achieving higher counts.
# - The right-skewed distribution highlights that while some high performers exist, they are relatively rare compared to the majority who achieve fewer perfect scores.
# - The combination of these plots provides a comprehensive view of the distribution and variation in perfect scores, useful for identifying trends and potential areas for improvement or further investigation.

# %%
DF_COPY.drop(columns=["Year","Type of Scam"],inplace=True)

# Comment 1:
# The "Year" column can be dropped from the dataset as it contains only a single, 
## consistent value ("2024") and therefore provides no additional information for analysis.

# Comment 2:
# The columns "Type of Scam" and "Actions Taken" could be considered synonymous for the 
## purpose of this analysis and can be treated as the target variable.

DF_COPY
# Out:
#   Region Exam Center  Number of Cases    Actions Taken  Average Marks  \
# 0  North           A               10  Exams Cancelled             85
# 1  South           B                0             None             81
# 2   East           C                0             None             78
# 3   West           D               12  Exams Cancelled             88
# 4  North           A                7  Exams Cancelled             83
# 5  South           B                0             None             80
# 6   West           D               15  Exams Cancelled             90
# 7   East           C                0             None             79
# 8  North           A                8  Exams Cancelled             84
#
#    Topper Marks  Number of Toppers  Number of Successful Candidates  \
# 0           100                 10                              200
# 1            99                  8                              205
# ...

# %%
DF_COPY.drop(columns=["Exam Center"],inplace=True)

# Comment
# The "Exam Center" column can be dropped as it appears to be redundant with the "Region" column.
## If each "Region" has a unique corresponding "Exam Center", then the "Region" column can
### sufficiently represent this information.

DF_COPY
# Out:
#   Region  Number of Cases    Actions Taken  Average Marks  Topper Marks  \
# 0  North               10  Exams Cancelled             85           100
# 1  South                0             None             81            99
# 2   East                0             None             78            98
# 3   West               12  Exams Cancelled             88           100
# 4  North                7  Exams Cancelled             83           100
# 5  South                0             None             80            99
# 6   West               15  Exams Cancelled             90           100
# 7   East                0             None             79            98
# 8  North                8  Exams Cancelled             84           100
#
#    Number of Toppers  Number of Successful Candidates  \
# 0                 10                              200
# 1                  8                              205
# 2                  5                              180
# ...

# %% [markdown]
# <font size = 5.5> Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder


label_encoder = LabelEncoder()


# Apply label encoding to the columns having "object" Data type
for col in DF_COPY.columns:
    if DF_COPY[col].dtype == "object":
        label_encoder = LabelEncoder()     # Initialize the LabelEncoder
        DF_COPY[col] = label_encoder.fit_transform(DF_COPY[col])

# Display the DataFrame        
DF_COPY
# Out:
#    Region  Number of Cases  Actions Taken  Average Marks  Topper Marks  \
# 0       1               10              0             85           100
# 1       2                0              1             81            99
# 2       0                0              1             78            98
# 3       3               12              0             88           100
# 4       1                7              0             83           100
# 5       2                0              1             80            99
# 6       3               15              0             90           100
# 7       0                0              1             79            98
# 8       1                8              0             84           100
#
#    Number of Toppers  Number of Successful Candidates  \
# 0                 10                              200
# 1                  8                              205
# 2                  5                              180
# ...

# %%
# Importing libraries 

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression,Ridge, Lasso, ElasticNet
from sklearn.metrics import r2_score,mean_squared_error
from math import sqrt

# %%
# Standardizing the dataset for faster convergence
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %% [markdown]
# Conclusion:
#
# 1. As on more than 50% of the centres of examination paper was leaked so there should be a re examination of neet UG 2024
#
# 2. Normal Distribution of Toppers

# %%
DF_COPY.mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1628\3694979831.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   DF_COPY.mean()
# Year                               2024.000000
# Number of Cases                       5.777778
# Average Marks                        83.111111
# Topper Marks                         99.333333
# Number of Toppers                     9.000000
# Number of Successful Candidates     196.666667
# Number of Perfect Scores              3.666667
# dtype: float64

# %%
DF_COPY.median()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1628\499520464.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   DF_COPY.median()
# Year                               2024.0
# Number of Cases                       7.0
# Average Marks                        83.0
# Topper Marks                        100.0
# Number of Toppers                     9.0
# Number of Successful Candidates     200.0
# Number of Perfect Scores              4.0
# dtype: float64
